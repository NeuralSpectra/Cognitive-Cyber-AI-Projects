# %% [markdown]
# # **Project 30: Bird Species Predictor**

# %% [markdown]
# ***numpy*** — *Brings in NumPy to handle fast numerical operations and arrays (the backbone of image and matrix processing).*
#
# ***cv2*** — *Imports OpenCV for computer vision tasks like image loading, processing, and object detection.*
#
# ***random*** — *Provides functions to generate random numbers or make random selections.*
#
# ***warnings*** — *Allows you to control, filter, or suppress warning messages during execution.*
#
# ***listdir*** — *Imports listdir to retrieve the list of files and folders inside a directory.*

# %%
import numpy as np
import cv2
import random
import warnings
from os import listdir

# %% [markdown]
# **Suppresses all warning messages so they are not displayed during program execution.**

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# **!pip install unrar — Installs the unrar utility so the system can handle .rar compressed files.**
#
# **!unrar x "/content/Bird Species Dataset.rar" — Extracts all contents of the RAR file into the current working directory.**

# %%
# !pip install unrar
# !unrar x "/content/Bird Species Dataset.rar"
# Out:
# Collecting unrar
#   Downloading unrar-0.4-py3-none-any.whl.metadata (3.0 kB)
# Downloading unrar-0.4-py3-none-any.whl (25 kB)
# Installing collected packages: unrar
# Successfully installed unrar-0.4
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/Bird Species Dataset.rar
#
# Creating    Bird Speciees Dataset                                     OK
# Creating    Bird Speciees Dataset/AMERICAN GOLDFINCH                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    Bird Speciees Dataset/BARN OWL                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    Bird Speciees Dataset/CARMINE BEE-EATER                   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    Bird Speciees Dataset/DOWNY WOODPECKER                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    Bird Speciees Dataset/EMPEROR PENGUIN                     OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    Bird Speciees Dataset/FLAMINGO                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %% [markdown]
# * **Sets the dataset directory, initializes image and label containers, and extracts sorted class names from folder structure.**
# * **Iterates through each class and its images, loading them from disk while skipping corrupted files.**
# * **Resizes all images to 150×150 and converts them to RGB for consistent model input.**
# * **Stores processed images and their corresponding class labels into lists.**
# * **Converts images and labels into NumPy arrays and normalizes pixel values to 0–1, then reports total images loaded.**

# %%
DATA_DIR = "/content/Bird Speciees Dataset"

image_list, label_list = [], []
classes = sorted(listdir(DATA_DIR))

print("Loading images...")
for cls in classes:
    for file in listdir(f"{DATA_DIR}/{cls}"):
        path = f"{DATA_DIR}/{cls}/{file}"
        img = cv2.imread(path)
        if img is None:
            continue
        img = cv2.resize(img, (150, 150))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        image_list.append(img)
        label_list.append(cls)

X = np.array(image_list, dtype="float32") / 255.0
y = np.array(label_list)

print(f"✓ Loaded {len(X)} images")
# Out:
# Loading images...
# ✓ Loaded 811 images

# %% [markdown]
# * **Imports TensorFlow as the core deep learning framework.**
# * **Imports Keras, TensorFlow’s high-level API for building and training neural networks.**
# * **Imports common neural network layers such as Dense, Conv2D, and MaxPooling.**
# * **Imports ImageDataGenerator for real-time image augmentation and preprocessing.**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# * **Imports a function to split data into training and testing sets.**
# * **Imports a tool to convert class labels into one-hot encoded format.**
# * **Imports a utility to compute class weights for handling imbalanced datasets.**
# * **Imports evaluation tools to generate a classification report and confusion matrix.**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# * **Initializes a LabelBinarizer to encode categorical labels.**
# * **Transforms the original class labels into one-hot encoded vectors.**
# * **Calculates the total number of unique classes in the dataset.**

# %%
lb = LabelBinarizer()
y_encoded = lb.fit_transform(y)
num_classes = len(lb.classes_)

# %% [markdown]
# * **Imports the pickle module for serializing Python objects.**
# * **Opens a file in write-binary mode to store the label classes.**
# * **Saves the class labels into the file using pickle.**
# * **Prints a confirmation message that labels have been saved.**

# %%
import pickle

with open("bird_labels.pickle", "wb") as f:
    pickle.dump(lb.classes_, f)

print("✓ Labels saved")
# Out:
# ✓ Labels saved

# %% [markdown]
# * **Splits the dataset into training and testing sets, keeping 20% for testing and preserving class distribution.**
# * **Further splits the training set into training and validation sets, again preserving class balance.**
# * **Converts one-hot encoded training labels back to class indices for tasks like class weighting or metrics.**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42, stratify=np.argmax(y_train, axis=1))

y_train_classes = np.argmax(y_train, axis=1)

# %% [markdown]
# * **Computes balanced class weights to handle class imbalance in the training set.**
# * **Stores the computed weights in a dictionary mapping class index to weight.**
# * **Prints the class weights for each bird species to verify the values.**

# %%
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train_classes), y=y_train_classes)

class_weight_dict = {i: w for i, w in enumerate(class_weights)}

print("Class Weights:")
for i, w in class_weight_dict.items():
    print(f"{lb.classes_[i]}: {w:.2f}")
# Out:
# Class Weights:
# AMERICAN GOLDFINCH: 0.95
# BARN OWL: 1.05
# CARMINE BEE-EATER: 1.03
# DOWNY WOODPECKER: 0.99
# EMPEROR PENGUIN: 0.97
# FLAMINGO: 1.02

# %% [markdown]
# * **Defines a function to create a convolutional neural network with a specified input shape and number of classes.**
# * **Uses multiple Conv2D layers with BatchNormalization, ReLU activation, MaxPooling, and Dropout for feature extraction and regularization.**
# * **Applies GlobalAveragePooling before the dense layers to reduce spatial dimensions.**
# * **Adds a fully connected Dense layer with L2 regularization, BatchNormalization, and Dropout to prevent overfitting.**
# * **Outputs a final Dense layer with softmax activation for multi-class classification and prints the model summary.**

# %%
def create_balanced_model(input_shape=(150,150,3), num_classes=6):
    model = keras.Sequential([

        layers.Conv2D(32, 3, padding="same", input_shape=input_shape),
        layers.BatchNormalization(), layers.Activation("relu"), layers.MaxPooling2D(), layers.Dropout(0.3),

        layers.Conv2D(64, 3, padding="same"), layers.BatchNormalization(), layers.Activation("relu"),
        layers.MaxPooling2D(), layers.Dropout(0.3),

        layers.Conv2D(128, 3, padding="same"), layers.BatchNormalization(), layers.Activation("relu"),
        layers.GlobalAveragePooling2D(), layers.Dropout(0.4),

        layers.Dense(128, activation="relu", kernel_regularizer=keras.regularizers.l2(0.01)),
        layers.BatchNormalization(), layers.Dropout(0.5),

        layers.Dense(num_classes, activation="softmax")

    ])
    return model

model = create_balanced_model(num_classes=num_classes)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 150, 150, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 75, 75, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 37, 37, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 37, 37, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,942 (437.27 KB)
#  Trainable params: 111,238 (434.52 KB)
#  Non-trainable params: 704 (2.75 KB)

# %% [markdown]
# * **Configures the model for training using the Adam optimizer with a learning rate of 0.001.**
# * **Sets categorical cross-entropy as the loss function for multi-class classification.**
# * **Tracks accuracy as the performance metric during training.**

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])

# %% [markdown]
# * **Creates an ImageDataGenerator to apply real-time data augmentation on training images.**
# * **Randomly rotates images up to 25 degrees to increase model robustness.**
# * **Shifts images horizontally and vertically by up to 15% to simulate different positions.**
# * **Applies random zoom up to 20% and horizontal flips for variety.**
# * **Uses nearest-neighbor filling for pixels introduced during transformations.**

# %%
datagen = ImageDataGenerator(rotation_range=25, width_shift_range=0.15, height_shift_range=0.15, zoom_range=0.2, horizontal_flip=True, fill_mode="nearest")

# %% [markdown]
# * **Sets up callbacks to control training behavior and improve performance.**
# * **EarlyStopping monitors validation loss and stops training if it doesn’t improve for 12 epochs, restoring the best weights.**
# * **ReduceLROnPlateau reduces the learning rate by half if validation loss plateaus for 5 epochs, down to a minimum of 1e-6.**

# %%
callbacks = [
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6)
]

# %% [markdown]
# * **Trains the model using augmented data generated in real-time from the training set.**
# * **Sets batch size to 32 and calculates steps per epoch based on training samples.**
# * **Runs for up to 80 epochs while validating on the validation set.**
# * **Uses previously defined callbacks to stop early or adjust learning rate automatically.**
# * **Applies class weights to handle imbalanced classes and prints progress during training.**

# %%
history = model.fit(datagen.flow(X_train, y_train, batch_size=32), steps_per_epoch=len(X_train)//32, epochs=80, validation_data=(X_val, y_val),
      callbacks=callbacks, class_weight=class_weight_dict, verbose=1)
# Out:
# Epoch 1/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 22s 742ms/step - accuracy: 0.2351 - loss: 3.6584 - val_accuracy: 0.2692 - val_loss: 3.0010 - learning_rate: 0.0010
# Epoch 2/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2188 - loss: 3.5098 - val_accuracy: 0.3077 - val_loss: 3.0000 - learning_rate: 0.0010
# Epoch 3/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.4366 - loss: 2.9504 - val_accuracy: 0.1615 - val_loss: 2.9884 - learning_rate: 0.0010
# Epoch 4/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4688 - loss: 2.4990 - val_accuracy: 0.1615 - val_loss: 2.9870 - learning_rate: 0.0010
# Epoch 5/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.5243 - loss: 2.7753 - val_accuracy: 0.1615 - val_loss: 2.9828 - learning_rate: 0.0010
# Epoch 6/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4688 - loss: 2.5518 - val_accuracy: 0.1615 - val_loss: 2.9814 - learning_rate: 0.0010
# Epoch 7/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - accuracy: 0.4670 - loss: 2.6053 - val_accuracy: 0.1615 - val_loss: 2.9399 - learning_rate: 0.0010
# Epoch 8/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4062 - loss: 2.6991 - val_accuracy: 0.1615 - val_loss: 2.9389 - learning_rate: 0.0010
# Epoch 9/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.5782 - loss: 2.3292 - val_accuracy: 0.1615 - val_loss: 2.9579 - learning_rate: 0.0010
# Epoch 10/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5625 - loss: 2.5143 - val_accuracy: 0.1615 - val_loss: 2.9596 - learning_rate: 0.0010
# Epoch 11/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.6126 - loss: 2.3146 - val_accuracy: 0.1615 - val_loss: 2.9438 - learning_rate: 0.0010
# Epoch 12/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5000 - loss: 2.4926 - val_accuracy: 0.1615 - val_loss: 2.9402 - learning_rate: 0.0010
# Epoch 13/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.6297 - loss: 2.1387 - val_accuracy: 0.1615 - val_loss: 2.9238 - learning_rate: 0.0010
# Epoch 14/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6250 - loss: 2.2672 - val_accuracy: 0.1615 - val_loss: 2.9230 - learning_rate: 0.0010
# Epoch 15/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.6017 - loss: 2.1990 - val_accuracy: 0.1615 - val_loss: 2.9216 - learning_rate: 0.0010
# Epoch 16/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6562 - loss: 2.0939 - val_accuracy: 0.1615 - val_loss: 2.9218 - learning_rate: 0.0010
# Epoch 17/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.6190 - loss: 2.1761 - val_accuracy: 0.1615 - val_loss: 2.9262 - learning_rate: 0.0010
# Epoch 18/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8333 - loss: 2.0729 - val_accuracy: 0.1615 - val_loss: 2.9267 - learning_rate: 0.0010
# Epoch 19/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.6741 - loss: 1.9849 - val_accuracy: 0.1615 - val_loss: 2.8747 - learning_rate: 0.0010
# Epoch 20/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7812 - loss: 1.6905 - val_accuracy: 0.1615 - val_loss: 2.8749 - learning_rate: 0.0010
# Epoch 21/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.6239 - loss: 1.9669 - val_accuracy: 0.1615 - val_loss: 2.8877 - learning_rate: 0.0010
# Epoch 22/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7500 - loss: 1.6290 - val_accuracy: 0.1615 - val_loss: 2.8861 - learning_rate: 0.0010
# Epoch 23/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.6879 - loss: 1.8914 - val_accuracy: 0.1615 - val_loss: 2.8391 - learning_rate: 0.0010
# Epoch 24/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6250 - loss: 1.8784 - val_accuracy: 0.1615 - val_loss: 2.8386 - learning_rate: 0.0010
# Epoch 25/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - accuracy: 0.6900 - loss: 1.8528 - val_accuracy: 0.1615 - val_loss: 2.8324 - learning_rate: 0.0010
# Epoch 26/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6875 - loss: 1.8336 - val_accuracy: 0.1615 - val_loss: 2.8302 - learning_rate: 0.0010
# Epoch 27/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.6987 - loss: 1.7142 - val_accuracy: 0.1615 - val_loss: 2.8349 - learning_rate: 0.0010
# Epoch 28/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7812 - loss: 1.7065 - val_accuracy: 0.1615 - val_loss: 2.8318 - learning_rate: 0.0010
# Epoch 29/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.7258 - loss: 1.6961 - val_accuracy: 0.1692 - val_loss: 2.7803 - learning_rate: 0.0010
# Epoch 30/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 1.6053 - val_accuracy: 0.1692 - val_loss: 2.7749 - learning_rate: 0.0010
# Epoch 31/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.6414 - loss: 1.9422 - val_accuracy: 0.2385 - val_loss: 2.7765 - learning_rate: 0.0010
# Epoch 32/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6875 - loss: 1.8405 - val_accuracy: 0.2462 - val_loss: 2.7630 - learning_rate: 0.0010
# Epoch 33/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - accuracy: 0.7197 - loss: 1.7024 - val_accuracy: 0.3154 - val_loss: 2.5282 - learning_rate: 0.0010
# Epoch 34/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8125 - loss: 1.6047 - val_accuracy: 0.3154 - val_loss: 2.5147 - learning_rate: 0.0010
# Epoch 35/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7463 - loss: 1.6298 - val_accuracy: 0.2923 - val_loss: 2.5452 - learning_rate: 0.0010
# Epoch 36/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 1.3196 - val_accuracy: 0.3000 - val_loss: 2.5395 - learning_rate: 0.0010
# Epoch 37/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.7282 - loss: 1.5052 - val_accuracy: 0.2462 - val_loss: 2.6778 - learning_rate: 0.0010
# Epoch 38/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8333 - loss: 1.5132 - val_accuracy: 0.2385 - val_loss: 2.7234 - learning_rate: 0.0010
# Epoch 39/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.7072 - loss: 1.6662 - val_accuracy: 0.4154 - val_loss: 2.4434 - learning_rate: 0.0010
# Epoch 40/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 1.7678 - val_accuracy: 0.4154 - val_loss: 2.4336 - learning_rate: 0.0010
# Epoch 41/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - accuracy: 0.7261 - loss: 1.4967 - val_accuracy: 0.2231 - val_loss: 2.4981 - learning_rate: 0.0010
# Epoch 42/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 1.2096 - val_accuracy: 0.2154 - val_loss: 2.5490 - learning_rate: 0.0010
# Epoch 43/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.7408 - loss: 1.5842 - val_accuracy: 0.3538 - val_loss: 2.3355 - learning_rate: 0.0010
# Epoch 44/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 1.1351 - val_accuracy: 0.3769 - val_loss: 2.3380 - learning_rate: 0.0010
# Epoch 45/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.7991 - loss: 1.3764 - val_accuracy: 0.4154 - val_loss: 2.1861 - learning_rate: 0.0010
# Epoch 46/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6562 - loss: 1.6017 - val_accuracy: 0.4000 - val_loss: 2.2028 - learning_rate: 0.0010
# Epoch 47/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 165ms/step - accuracy: 0.7607 - loss: 1.4236 - val_accuracy: 0.3692 - val_loss: 2.1719 - learning_rate: 0.0010
# Epoch 48/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8438 - loss: 1.2299 - val_accuracy: 0.3846 - val_loss: 2.1771 - learning_rate: 0.0010
# Epoch 49/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.7785 - loss: 1.3987 - val_accuracy: 0.5000 - val_loss: 1.9694 - learning_rate: 0.0010
# Epoch 50/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8750 - loss: 1.1959 - val_accuracy: 0.5308 - val_loss: 1.9585 - learning_rate: 0.0010
# Epoch 51/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 236ms/step - accuracy: 0.7734 - loss: 1.3122 - val_accuracy: 0.4154 - val_loss: 2.0370 - learning_rate: 0.0010
# Epoch 52/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8125 - loss: 1.1086 - val_accuracy: 0.4000 - val_loss: 2.0918 - learning_rate: 0.0010
# Epoch 53/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.7346 - loss: 1.4914 - val_accuracy: 0.4462 - val_loss: 2.1202 - learning_rate: 0.0010
# Epoch 54/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5000 - loss: 2.2253 - val_accuracy: 0.4077 - val_loss: 2.2663 - learning_rate: 0.0010
# Epoch 55/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.8199 - loss: 1.2499 - val_accuracy: 0.3231 - val_loss: 2.5158 - learning_rate: 0.0010
# Epoch 56/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6562 - loss: 1.8279 - val_accuracy: 0.3462 - val_loss: 2.4664 - learning_rate: 5.0000e-04
# Epoch 57/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - accuracy: 0.7816 - loss: 1.3078 - val_accuracy: 0.6692 - val_loss: 1.5112 - learning_rate: 5.0000e-04
# Epoch 58/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7500 - loss: 1.2691 - val_accuracy: 0.6769 - val_loss: 1.5053 - learning_rate: 5.0000e-04
# Epoch 59/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - accuracy: 0.8023 - loss: 1.2107 - val_accuracy: 0.5846 - val_loss: 1.5710 - learning_rate: 5.0000e-04
# Epoch 60/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9062 - loss: 1.0719 - val_accuracy: 0.5923 - val_loss: 1.5512 - learning_rate: 5.0000e-04
# Epoch 61/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.8173 - loss: 1.2746 - val_accuracy: 0.6538 - val_loss: 1.3747 - learning_rate: 5.0000e-04
# Epoch 62/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8125 - loss: 1.1115 - val_accuracy: 0.6846 - val_loss: 1.3497 - learning_rate: 5.0000e-04
# Epoch 63/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.7819 - loss: 1.3189 - val_accuracy: 0.7000 - val_loss: 1.3246 - learning_rate: 5.0000e-04
# Epoch 64/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7500 - loss: 1.3861 - val_accuracy: 0.7000 - val_loss: 1.3165 - learning_rate: 5.0000e-04
# Epoch 65/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.7806 - loss: 1.2191 - val_accuracy: 0.6385 - val_loss: 1.4061 - learning_rate: 5.0000e-04
# Epoch 66/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8125 - loss: 1.1206 - val_accuracy: 0.6154 - val_loss: 1.4433 - learning_rate: 5.0000e-04
# Epoch 67/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - accuracy: 0.7903 - loss: 1.2430 - val_accuracy: 0.7308 - val_loss: 1.2995 - learning_rate: 5.0000e-04
# Epoch 68/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9375 - loss: 0.9068 - val_accuracy: 0.7462 - val_loss: 1.2924 - learning_rate: 5.0000e-04
# Epoch 69/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.7773 - loss: 1.1866 - val_accuracy: 0.6231 - val_loss: 1.4193 - learning_rate: 5.0000e-04
# Epoch 70/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6667 - loss: 1.1659 - val_accuracy: 0.6692 - val_loss: 1.4108 - learning_rate: 5.0000e-04
# Epoch 71/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.8089 - loss: 1.1814 - val_accuracy: 0.7462 - val_loss: 1.2753 - learning_rate: 5.0000e-04
# Epoch 72/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9062 - loss: 1.0013 - val_accuracy: 0.7462 - val_loss: 1.2606 - learning_rate: 5.0000e-04
# Epoch 73/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.8492 - loss: 1.0858 - val_accuracy: 0.7923 - val_loss: 1.1841 - learning_rate: 5.0000e-04
# Epoch 74/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 1.0539 - val_accuracy: 0.7923 - val_loss: 1.2031 - learning_rate: 5.0000e-04
# Epoch 75/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - accuracy: 0.8075 - loss: 1.1142 - val_accuracy: 0.7308 - val_loss: 1.2231 - learning_rate: 5.0000e-04
# Epoch 76/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8125 - loss: 1.1370 - val_accuracy: 0.7077 - val_loss: 1.2363 - learning_rate: 5.0000e-04
# Epoch 77/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.8117 - loss: 1.1358 - val_accuracy: 0.7154 - val_loss: 1.2728 - learning_rate: 5.0000e-04
# Epoch 78/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8125 - loss: 1.1087 - val_accuracy: 0.7538 - val_loss: 1.2262 - learning_rate: 5.0000e-04
# Epoch 79/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.8092 - loss: 1.1185 - val_accuracy: 0.7462 - val_loss: 1.2099 - learning_rate: 2.5000e-04
# Epoch 80/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 1.0829 - val_accuracy: 0.7538 - val_loss: 1.1919 - learning_rate: 2.5000e-04

# %% [markdown]
# * **Uses the trained model to predict class probabilities for the test set.**
# * **Converts predicted probabilities into class indices using argmax.**
# * **Converts one-hot encoded true labels into class indices for evaluation.**

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step

# %% [markdown]
# * **Prints a detailed classification report showing precision, recall, F1-score, and support for each class.**
# * **Prints the confusion matrix to visualize correct and incorrect predictions across all classes.**

# %%
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=lb.classes_))

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Classification Report:
#                     precision    recall  f1-score   support
#
# AMERICAN GOLDFINCH       1.00      0.79      0.88        29
#           BARN OWL       0.64      0.96      0.77        26
#  CARMINE BEE-EATER       0.91      0.77      0.83        26
#   DOWNY WOODPECKER       0.90      0.68      0.78        28
#    EMPEROR PENGUIN       0.66      0.96      0.78        28
#           FLAMINGO       1.00      0.65      0.79        26
#
#           accuracy                           0.80       163
#          macro avg       0.85      0.80      0.81       163
#       weighted avg       0.85      0.80      0.81       163
#
#
# Confusion Matrix:
# [[23  4  0  1  1  0]
#  [ 0 25  0  1  0  0]
#  [ 0  3 20  0  3  0]
#  [ 0  3  0 19  6  0]
#  [ 0  1  0  0 27  0]
#  [ 0  3  2  0  4 17]]

# %% [markdown]
# * **Saves the trained model to a file named Bird Classifier.keras for later use or deployment.**
# * **Prints confirmation that both the model and the previously saved label file are stored successfully.**

# %%
model.save("Bird Classifier.keras")
print("\n✓ Bird Classifier.keras saved")
print("✓ bird_labels.pickle saved")
# Out:
# ✓ Bird Classifier.keras saved
# ✓ bird_labels.pickle saved
